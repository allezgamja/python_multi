# %% [markdown]
# # 이미지 데이터 셋을 이용한 CNN Modeling(Google Drive Mount)
# ## Dogs and Cats Image_Data
# * Train_Data : 2000(1000_Dogs, 1000_Cats)
# * Valid_Data : 1000(500_Dogs, 500_Cats)
# * Test_Data : 1000(500_Dogs, 500_Cats)

# %% [markdown]
# ## Import Tensorflow & Keras

# %% [markdown]
# * TensorFlow Version 지정

# %%
# %tensorflow_version 1.x
import tensorflow as tf

tf.__version__
# Out:
# '1.15.0'

# %% [markdown]
# * GPU 설정 확인

# %%
print('GPU Information -', tf.test.gpu_device_name(), '\n')

# !nvidia-smi
# Out:
# GPU Information - /device:GPU:0
#
# Fri Feb 21 00:35:27 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.48.02    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P0    28W /  70W |    111MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# * Keras Version 확인

# %%
import keras

keras.__version__
# Out:
# Using TensorFlow backend.
# '2.2.5'

# %% [markdown]
# # I. Google Drive Mount
# * 'dogs_and_cats_small' 디렉토리를 구글드라이브에 업로드

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# * 마운트 결과 확인

# %%
# !ls -l '/content/drive/My Drive/Colab Notebooks/datasets/dogs_and_cats_small'
# Out:
# total 12
# drwx------ 2 root root 4096 Sep 12 03:18 test
# drwx------ 2 root root 4096 Sep 12 03:18 train
# drwx------ 2 root root 4096 Sep 12 03:18 validation

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Image_File Directory Setting

# %% [markdown]
# * base_dir
# * train_dir
# * validation_dir
# * test_dir

# %%
import os

base_dir = '/content/drive/My Drive/Colab Notebooks/datasets/dogs_and_cats_small'

train_dir = os.path.join(base_dir, 'train')
valid_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

# %% [markdown]
# > ## 2) ImageDataGenerator( ) & flow_from_directory( )

# %% [markdown]
# * Normalization
#  * ImageDataGenerator( )
# * Resizing & Generator
#  * flow_from_directory( )

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255)
valid_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = train_datagen.flow_from_directory(
                  train_dir,
                  target_size = (150, 150),
                  batch_size = 20,
                  class_mode = 'binary')

valid_generator = valid_datagen.flow_from_directory(
                  valid_dir,
                  target_size = (150, 150),
                  batch_size = 20,
                  class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# > ## 3) Test train_generator

# %%
for data_batch, labels_batch in train_generator:
    print('배치 데이터 크기:', data_batch.shape)
    print('배치 레이블 크기:', labels_batch.shape)
    break
# Out:
# 배치 데이터 크기: (20, 150, 150, 3)
# 배치 레이블 크기: (20,)

# %% [markdown]
# # III. CNN Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * Feature Extraction & Classification

# %%
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation = 'relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation = 'relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation = 'relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation = 'relu'))
model.add(layers.Dense(1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               3211776
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
model.compile(loss = 'binary_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 모델 학습 수행
#  * 약 30분

# %%
Hist_dandc = model.fit_generator(train_generator,
                                 steps_per_epoch = 100,
                                 epochs = 60,
                                 validation_data = valid_generator,
                                 validation_steps = 50)
# Out:
# Epoch 1/60
# 100/100 [==============================] - 12s 122ms/step - loss: 0.7857 - acc: 0.5080 - val_loss: 0.6982 - val_acc: 0.5000
# Epoch 2/60
# 100/100 [==============================] - 11s 108ms/step - loss: 0.6948 - acc: 0.5630 - val_loss: 0.6600 - val_acc: 0.6170
# Epoch 3/60
# 100/100 [==============================] - 11s 111ms/step - loss: 0.6461 - acc: 0.6225 - val_loss: 0.6195 - val_acc: 0.6460
# Epoch 4/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.6002 - acc: 0.6745 - val_loss: 0.5941 - val_acc: 0.6880
# Epoch 5/60
# 100/100 [==============================] - 11s 111ms/step - loss: 0.5409 - acc: 0.7280 - val_loss: 0.5676 - val_acc: 0.7080
# Epoch 6/60
# 100/100 [==============================] - 11s 113ms/step - loss: 0.4833 - acc: 0.7750 - val_loss: 0.7119 - val_acc: 0.6770
# Epoch 7/60
# 100/100 [==============================] - 11s 112ms/step - loss: 0.4426 - acc: 0.7970 - val_loss: 0.6701 - val_acc: 0.6900
# Epoch 8/60
# 100/100 [==============================] - 11s 111ms/step - loss: 0.3731 - acc: 0.8315 - val_loss: 0.7347 - val_acc: 0.7020
# Epoch 9/60
# 100/100 [==============================] - 11s 110ms/step - loss: 0.3185 - acc: 0.8600 - val_loss: 0.6420 - val_acc: 0.7200
# Epoch 10/60
# 100/100 [==============================] - 11s 113ms/step - loss: 0.2530 - acc: 0.8875 - val_loss: 0.8113 - val_acc: 0.7310
# Epoch 11/60
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2038 - acc: 0.9165 - val_loss: 0.9067 - val_acc: 0.6910
# Epoch 12/60
# 100/100 [==============================] - 11s 110ms/step - loss: 0.1848 - acc: 0.9375 - val_loss: 1.0642 - val_acc: 0.7070
# Epoch 13/60
# 100/100 [==============================] - 11s 110ms/step - loss: 0.1255 - acc: 0.9575 - val_loss: 1.0845 - val_acc: 0.7260
# Epoch 14/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.1156 - acc: 0.9650 - val_loss: 1.2490 - val_acc: 0.7470
# Epoch 15/60
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0923 - acc: 0.9675 - val_loss: 1.1551 - val_acc: 0.7310
# Epoch 16/60
# 100/100 [==============================] - 11s 110ms/step - loss: 0.1015 - acc: 0.9710 - val_loss: 1.6932 - val_acc: 0.7050
# Epoch 17/60
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0758 - acc: 0.9765 - val_loss: 1.6568 - val_acc: 0.7390
# Epoch 18/60
# 100/100 [==============================] - 11s 113ms/step - loss: 0.0613 - acc: 0.9825 - val_loss: 1.9147 - val_acc: 0.7030
# Epoch 19/60
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0772 - acc: 0.9805 - val_loss: 2.5509 - val_acc: 0.6200
# Epoch 20/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0530 - acc: 0.9835 - val_loss: 1.9384 - val_acc: 0.7020
# Epoch 21/60
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0562 - acc: 0.9825 - val_loss: 1.8151 - val_acc: 0.7360
# Epoch 22/60
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0484 - acc: 0.9815 - val_loss: 1.9837 - val_acc: 0.7190
# Epoch 23/60
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0523 - acc: 0.9860 - val_loss: 2.0697 - val_acc: 0.7090
# Epoch 24/60
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0501 - acc: 0.9885 - val_loss: 2.0818 - val_acc: 0.7350
# Epoch 25/60
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0541 - acc: 0.9860 - val_loss: 2.3053 - val_acc: 0.7400
# Epoch 26/60
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0688 - acc: 0.9845 - val_loss: 2.4046 - val_acc: 0.6600
# Epoch 27/60
# 100/100 [==============================] - 11s 112ms/step - loss: 0.0343 - acc: 0.9880 - val_loss: 2.1550 - val_acc: 0.7420
# Epoch 28/60
# 100/100 [==============================] - 11s 115ms/step - loss: 0.0103 - acc: 0.9955 - val_loss: 2.3740 - val_acc: 0.7250
# Epoch 29/60
# 100/100 [==============================] - 11s 114ms/step - loss: 0.0640 - acc: 0.9850 - val_loss: 2.2537 - val_acc: 0.7110
# Epoch 30/60
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0226 - acc: 0.9920 - val_loss: 2.4604 - val_acc: 0.7110
# Epoch 31/60
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0718 - acc: 0.9820 - val_loss: 2.7310 - val_acc: 0.7210
# Epoch 32/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0558 - acc: 0.9815 - val_loss: 2.3546 - val_acc: 0.7130
# Epoch 33/60
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0950 - acc: 0.9810 - val_loss: 1.6603 - val_acc: 0.6900
# Epoch 34/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0234 - acc: 0.9925 - val_loss: 2.2145 - val_acc: 0.7110
# Epoch 35/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0784 - acc: 0.9880 - val_loss: 2.4923 - val_acc: 0.7280
# Epoch 36/60
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0658 - acc: 0.9885 - val_loss: 2.9200 - val_acc: 0.6880
# Epoch 37/60
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0415 - acc: 0.9905 - val_loss: 2.7233 - val_acc: 0.7140
# Epoch 38/60
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0366 - acc: 0.9920 - val_loss: 2.3017 - val_acc: 0.7370
# Epoch 39/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0750 - acc: 0.9890 - val_loss: 2.6434 - val_acc: 0.7280
# Epoch 40/60
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0480 - acc: 0.9880 - val_loss: 2.6635 - val_acc: 0.6950
# Epoch 41/60
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0787 - acc: 0.9885 - val_loss: 2.7371 - val_acc: 0.7280
# Epoch 42/60
# 100/100 [==============================] - 11s 105ms/step - loss: 0.0509 - acc: 0.9900 - val_loss: 2.5480 - val_acc: 0.7150
# Epoch 43/60
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0320 - acc: 0.9930 - val_loss: 2.7571 - val_acc: 0.6710
# Epoch 44/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0064 - acc: 0.9980 - val_loss: 3.1462 - val_acc: 0.6920
# Epoch 45/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0631 - acc: 0.9905 - val_loss: 2.6580 - val_acc: 0.7330
# Epoch 46/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.1063 - acc: 0.9860 - val_loss: 2.1720 - val_acc: 0.7210
# Epoch 47/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0629 - acc: 0.9875 - val_loss: 2.7725 - val_acc: 0.7180
# Epoch 48/60
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0856 - acc: 0.9895 - val_loss: 2.9058 - val_acc: 0.7180
# Epoch 49/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0385 - acc: 0.9915 - val_loss: 2.9064 - val_acc: 0.7380
# Epoch 50/60
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0536 - acc: 0.9895 - val_loss: 3.0932 - val_acc: 0.7010
# Epoch 51/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0272 - acc: 0.9965 - val_loss: 3.5570 - val_acc: 0.7250
# Epoch 52/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0812 - acc: 0.9885 - val_loss: 3.1167 - val_acc: 0.7240
# Epoch 53/60
# 100/100 [==============================] - 11s 105ms/step - loss: 0.0642 - acc: 0.9930 - val_loss: 4.7324 - val_acc: 0.6720
# Epoch 54/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0749 - acc: 0.9920 - val_loss: 3.2520 - val_acc: 0.7380
# Epoch 55/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0517 - acc: 0.9910 - val_loss: 2.8914 - val_acc: 0.7330
# Epoch 56/60
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0525 - acc: 0.9910 - val_loss: 2.5448 - val_acc: 0.6890
# Epoch 57/60
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0654 - acc: 0.9895 - val_loss: 3.5143 - val_acc: 0.7210
# Epoch 58/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0508 - acc: 0.9920 - val_loss: 2.9223 - val_acc: 0.7380
# Epoch 59/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0469 - acc: 0.9935 - val_loss: 3.7473 - val_acc: 0.7000
# Epoch 60/60
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0988 - acc: 0.9850 - val_loss: 3.3726 - val_acc: 0.7090

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_dandc.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_dandc.history['loss'])
plt.plot(epochs, Hist_dandc.history['val_loss'])

plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * test_generator

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_generator = test_datagen.flow_from_directory(
                 test_dir,
                 target_size = (150, 150),
                 batch_size = 20,
                 class_mode = 'binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# * Loss & Accuracy
#  * 약 7분

# %%
loss, accuracy = model.evaluate_generator(test_generator,
                                          steps = 50)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# Loss = 3.51661
# Accuracy = 0.70200

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
