# %% [markdown]
# ### 정보처리.png 문제 class 이용하여 작성

# %%
abc = open('./data/Abc1115.txt')
lines = abc.readlines()
lines
# Out:
# ['990001addx 17 29 16 49 43154CAC\n',
#  '990002stch 30  9 48 25 81193CAA\n',
#  '990003gali 93 60  6 84 36279ACA\n',
#  '990004miat 73 22 48 24 72239BCC\n',
#  '990005oran 33 38 59 58 28216CBA\n',
#  '990006sj24 27 65 54 77 33256BAA\n',
#  '990007kor2 33 85 98 60 66342ABA\n',
#  '990008vsky 41  5 99 14 67226CAC\n',
#  '990009kimd 74  4  1 33 53165BCA\n',
#  '990010blue 55 84 50 89 37315ABA\n',
#  '990011moja 43 69 68 23 92295BAC\n',
#  '990012bleu 15  5 19 97 88224BCC\n',
#  '990013lore 77 85 36 95 46339BAC\n',
#  '990014oldn 83 89 67 67 87393BCA\n',
#  '990015sire 66 45 86 93 48338CBA\n',
#  '990016klaa 73  4 40 31 95243ABC\n',
#  '990017rsh1 47  1 63 63 22196BAA\n',
#  '990018vict 79 17 32 29 85242CAC\n',
#  '990019popy 95 65 65 29 75329BAC\n',
#  '990020kbsu 37 52 24 37 93243CAC\n',
#  '990021equi 13 95 56 93 88345BCB\n',
#  '990022schn 19 92 49 84 54298ABA\n',
#  '990023tess 86 71 87  6 15265BCB\n',
#  '990024mula 48 41 18 32 46185ABC\n',
#  '990025lyj2 24 90 72 29 52267BAB\n',
# ...

# %%
student_data = []
for line in lines:
    std_no = line[0:6]    # line[0:6] = lines[i][0:6]
    email = line[6:10]
    kor = int(line[10:13])
    eng = int(line[13:16])
    math = int(line[16:19])
    sci = int(line[19:22])
    hist = int(line[22:25])
    tot = int(line[25:28])
    mcode = line[28:29]
    acode = line[29:30]
    lcode = line[30:31]
    temp = [std_no,email,kor,eng,math,sci,hist,tot,mcode,acode,lcode]
    student_data.append(temp)
    pass
student_data
# Out:
# [['990001', 'addx', 17, 29, 16, 49, 43, 154, 'C', 'A', 'C'],
#  ['990002', 'stch', 30, 9, 48, 25, 81, 193, 'C', 'A', 'A'],
#  ['990003', 'gali', 93, 60, 6, 84, 36, 279, 'A', 'C', 'A'],
#  ['990004', 'miat', 73, 22, 48, 24, 72, 239, 'B', 'C', 'C'],
#  ['990005', 'oran', 33, 38, 59, 58, 28, 216, 'C', 'B', 'A'],
#  ['990006', 'sj24', 27, 65, 54, 77, 33, 256, 'B', 'A', 'A'],
#  ['990007', 'kor2', 33, 85, 98, 60, 66, 342, 'A', 'B', 'A'],
#  ['990008', 'vsky', 41, 5, 99, 14, 67, 226, 'C', 'A', 'C'],
#  ['990009', 'kimd', 74, 4, 1, 33, 53, 165, 'B', 'C', 'A'],
#  ['990010', 'blue', 55, 84, 50, 89, 37, 315, 'A', 'B', 'A'],
#  ['990011', 'moja', 43, 69, 68, 23, 92, 295, 'B', 'A', 'C'],
#  ['990012', 'bleu', 15, 5, 19, 97, 88, 224, 'B', 'C', 'C'],
#  ['990013', 'lore', 77, 85, 36, 95, 46, 339, 'B', 'A', 'C'],
#  ['990014', 'oldn', 83, 89, 67, 67, 87, 393, 'B', 'C', 'A'],
#  ['990015', 'sire', 66, 45, 86, 93, 48, 338, 'C', 'B', 'A'],
# ...

# %%
class StudentData:
    def __init__(self,std_no,email,kor,eng,math,sci,hist,tot,mcode,acode,lcode):
        self.std_no = std_no
        self.email = email
        self.kor = kor
        self.eng = eng
        self.math = math
        self.sci = sci
        self.hist = hist
        self.tot = tot
        self.mcode = mcode
        self.acode = acode
        self.lcode = lcode
        pass
    
    def get_koreng(self):
        koreng = self.kor + self.eng
        for i in range(0, len(student_data)+1):
            student_data[i] += koreng
        sorted(student_data, key=lambda student: student_data[11])
    
    pass

# %%
# sample
from example.gisa import gisa_data
class GisaTest:
    
    def __init__(self,lines):
        
        pass
    
    def make_student(self,lines):
        data = []
        
        return data
    
    def solve_1(self):
        result = 0

# %%
def

# %%
### 모스부호.png를 이용한 프로그램 만들기
- 영어를 모스부호로
- 모스부호를 영어로
- class 이용하기
